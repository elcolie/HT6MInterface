# %% [markdown]
# <a href="https://colab.research.google.com/github/elcolie/HT6MInterface/blob/master/calibration_production_pressure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
one = {'param': ['oil_rate', 'water_rate', 'form_gas_rate', 'injection_rate', 'production_pressure', 'injection_pressure', 'max_lift_depth'], 'val': [1, 1, 0.7149466573712432, 1, 1, 1, 0.0]}
two = {'param': ['oil_rate', 'water_rate', 'form_gas_rate', 'injection_rate', 'production_pressure', 'injection_pressure', 'max_lift_depth'], 'val': [1, 1, 0.5989250081087811, 1.2345607057750392, 1, 1, 0.0]}
three = {'param': ['oil_rate', 'water_rate', 'form_gas_rate', 'injection_rate', 'production_pressure', 'injection_pressure', 'max_lift_depth'], 'val': [1, 1.252945450172514, 0.9191211316891883, 1.412692516561274, 1, 1, 0]}
four = {'param': ['oil_rate', 'water_rate', 'form_gas_rate', 'injection_rate', 'production_pressure', 'injection_pressure', 'max_lift_depth'], 'val': [1.1264913462514539, 1.1264913462514539, 0.6751213517791469, 1.5795638291230438, 1, 1, 0]}

# %%
import pandas as pd

# %%
df_1 = pd.DataFrame.from_dict(one)
df_2 = pd.DataFrame.from_dict(two)
df_3 = pd.DataFrame.from_dict(three)
df_4 = pd.DataFrame.from_dict(four)

# %%
df_1.plot.bar(x='param', y='val', rot=10)
df_2.plot.bar(x='param', y='val', rot=10)
df_3.plot.bar(x='param', y='val', rot=10)
df_4.plot.bar(x='param', y='val', rot=10)
